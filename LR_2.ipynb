# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 800, 10000)
x
# Out:
# array([0.00000000e+00, 8.00080008e-02, 1.60016002e-01, ...,
#        7.99839984e+02, 7.99919992e+02, 8.00000000e+02])

# %%
y = 400 + np.random.random(10000)*400 + x*0.002
y
# Out:
# array([422.61351895, 733.01829961, 654.39298038, ..., 567.00722862,
#        510.32948244, 669.41770648])

# %%
lr = LinearRegression()
lr.fit(x.reshape(-1, 1), y)
print 'intercept = %f, slope = %f' % (lr.intercept_, lr.coef_)
# Out:
# intercept = 601.491046, slope = -0.003118

# %%
y_hat = lr.predict(x.reshape(-1, 1))
plt.figure(figsize=[8, 6])
plt.scatter(x, y, s=0.2)
plt.plot(x, y_hat, c='red')
plt.xlabel('pm_suzhou')
plt.ylabel('pm_hangzhou')
